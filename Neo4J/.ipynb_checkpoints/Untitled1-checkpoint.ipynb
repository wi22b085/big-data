# %% [markdown]
# # NEO4J

# %% [markdown]
# ## Theoretische Hintergründe

# %% [markdown]
# ### Allgemeines & Konzepte
#
# Neo4J ist eine NOSQL-Datenbank und gehört unter diesen den Graphdatenbanken an.
# Anders als traditionelle Datenbanksysteme, verwendet Neo4J als Graphdatenbank Knoten(Nodes) und Kanten(Edges) anstelle von Zeilen und Tabellen. Knoten repräsentieren Entitäten wie Personen, Städte oder Konten.
#
#  Knoten können Eigenschaften haben wie (Nach)Namen, E-Mail usw. Die Kanten verbinden die Knoten und definieren die Beziehungen. Sie haben eine Richtung, einen Typ und können Eigenschaften vorweisen.
# Am Beispiel von Social Media würde das bedeuten: Die Richtung bedeutet, wer wem folgt. Der Typ beschreibt die Art der Beziehung „Ist-Follower“. Die Eigenschaften einer Beziehung beschreiben die Beziehung näher. Zum Beispiel: An welchem Tag hat Person A Person B abonniert.![image.png](attachment:5db88092-8c26-4206-95a4-708bd28a1229.png)![image.png](attachment:3bda42fc-3255-4fcc-85c5-f8051e7c19e4.png)
#
# Da Beziehungen direkt in Neo4J abgespeichert werden, ist die Abfrage komplexer Beziehungen weitaus effizienter als in anderen Datenbankmodellen

# %% [markdown]
# ### Konzepte
# **ACID – Wie traditionelle Datenbanken werden ACID-Transaktionen unterstützt**
# - Abgeschlossenheit – ganz oder gar nicht
# - Konsistenz – Integritätsbedingungen müssen eingehalten werden
# - Isolation – verhindert, dass sich gleichzeitig ablaufende Transaktionen behindern
# - Dauerhaftigkeit – einmal abgespeichert bleibt es
#
# **Flexbilität – Knoten, Beziehungen oder Eigenschaften hinzufügen, abändern**
# - Cypher Query Language – eigene Abfragesprache namens Cypher -> die Sprache ähnelt dem Muster von Graphen
# - Horizontale Skalierbarkeit – Neo4J kann auf mehre Maschinen verteilt werden, um Leistung und Kapazität zu erhöhen

# %% [markdown]
# ### Documentation
# Neo4J Inc. - die Firma hinter Neo4J - bietet eine umfangreiche Dokumentation auf ihrer Webseite an: https://neo4j.com/docs/
#
# Außerdem gibt es E-Learning-Inhalte. Zum Beispiel die Neo4J Graph Academy, in der neue Nutzer zwischen mehreren Leitfäden, die die Grundlagen von Neo4J erklären, und fortgeschrittenen Tutorials wählen können:
# https://graphacademy.neo4j.com/

# %% [markdown]
# ### Installations-Anleitung
# Anbei die wichtigsten Schritte für die Installation von Neo4J.
# Voraussetzungen: OpenJDK17 or Oracle Java 17; JVM (minimum would be JRE)
#
# Link to installation guide (local):
#
# https://neo4j.com/docs/operations-manual/current/installation/windows/
#
# Docker Installation
#
# docker pull neo4j
#
#
# docker run --name neo4j-container -p7474:7474 -p7687:7687 -d neo4j

# %% [markdown]
# ### Anwendungsbereiche
# Neo4J und andere Graph Databases eignen sich am besten für eng verbundene Daten. Übliche Einsatzgebiete, wo dieses Kriterium zutrifft, sind:
#
# - Betrugserkennung:
# Graph Databases können dabei helfen, Betrugsversuche, wie Kreditkartenbetrug oder Geldwäsche zu stoppen. Beispielsweise kann ein Graph die Interaktionen zwischen Personen mit ihren Telefonnummern, Geräten und IP-Adressen beschreiben. Dadurch werden verdächtige Muster aufgedeckt, wie mehrere Benutzer, die die selbe IP-Adresse nutzen.
#
# - Real-Time Recommendations:
# Graph Databases können Echtzeitempfehlungen erstellen. Hier kann der Graph die Kaufhistorie oder der Suchverlauf eines Benutzers gespeichert werden. Dadurch können ähnliche Produkte sofort vorgeschlagen werden. Es könnte auch eine Verbindung zwischen ähnlcihen Benutzern hergestellt werden. Anschließend könnten die gekauften Produkte dieser ähnlichen Benutzer vorgestellt werden.
#
# - Soziale Netzwerke:
# Graph Databases können Informationen über soziale Netzwerke speichern. Zum Beispiel können die Mitarbeiter eines Unternehmens, die Projekte, an denen sie arbeiten und die Beziehungen zwischen den Mitarbeitern dargestellt werden. Bei einer Social Media Plattform könnten zu den Benutzern auch die Beziehungen zu anderen Benutzern, die von ihnen verfassten Beiträge und Likes gespeichert werden.
#
# Neo4J und andere Graph Databases sollten also nur genutzt werden, wenn die zu speichernden Daten eng miteinander verbunden sind und diese Verbindung auch von Bedeutung ist. Neo4J kann auch allgemeine Suchen durchführen, bei denen der gesamte Graph ohne einen spezifischen Ausgangspunkt durchsucht wird. Hiefür sind Graph Databases aber nicht die beste Option, da sie für solche Queries nicht optimiert sind.

# %% [markdown]
# ### Stärken & Schwächen
# #### Stärken
# - Flexibilität:
# Neo4J und andere Graph Databases sind flexibel. Daher muss die endgültige Struktur eines Graphen nicht im Voraus definieren werden. Nodes und Edges können hinzugefügt oder gelöscht werden, ohne dass die bereits gespeicherten Informationen beachtet werden müssen.
#
# - Performance:
# Diese Art von Datenbank muss keine Joins durchführen, die potenziell zeitaufwändig sind. Stattdessen kann man Edges von Node zu Node folgen, was einfacher und schneller ist.
#
# - Einfache Darstellung der Daten:
# Graph Databases ermöglichen eine einfache Darstellung der Daten. Die Struktur des Graphen ist sehr intuitiv und erleichtert das Verständnis der Datenbank.
# #### Schwächen
# - Erschwerte Skalierung:
# Horizontale Skalierung in Graph Datenbases ist möglich, aber schwieriger als bei anderen NoSQL-Datenbanken. Das hat den Grund, dass der Graph über mehrere Maschinen miteinander verbunden sein muss.
#
# - Schlechte Performance bei Umgang mit großen Werten:
# Graph Databases haben bei Daten mit sehr großen Werten, wie BLOBs oder CLOBs eine geringe Leistung.
#
# - Keine einheitliche Query Language:
# Graph Databases haben keine einheitliche Query Language. Deshalb müssen viele Entwickler eine neue Query Language, wie Cypher oder Gremlin lernen. Bei Neo4J ist die Nutzung von Cypher notwendig.

# %% [markdown]
# ### Weitere Eigenschaften
#
# Sicherheit: Neo4j verfügt über robuste Sicherheitsfunktionen, aber wie bei jeder Datenbank ist es entscheidend, sie richtig zu konfigurieren, um Ihre Daten zu schützen.
#
# Um nur einige der Sicherheitsfunktionen zu nennen:
#
# Authentifizierung und Autorisierung: Eingebaute Benutzerauthentifizierung und benutzerabhängige Autorisierung.
#
# Verschlüsselung: Die Daten werden verschlüsselt.
#
# Integration: Neo4j bietet gute Integrationsmöglichkeiten mit verschiedenen Programmiersprachen und Frameworks, was es vielseitig für unterschiedliche Entwicklungsumgebungen macht.
#
# Um nur einige Integrationsmöglichkeiten zu nennen:
#
# Dazu gehören die Integration verschiedener Frameworks (im Java-Umfeld z.B. Spring Data Neo4J), Sprachunterstützung für viele verschiedene Programmiersprachen (Java, Python, JavaScript (Node.js), .NET etc.), aber auch Neo4J-spezifische Protokolle wie Neo4J Bolt oder die eigene HTTP-API.
# Verschiedene Editionen: Die Community Edition ist Open-Source, es gibt aber auch eine Enterprise Edition Edition.

# %% [markdown]
# ## Anwendung in der Praxis

# %% [markdown]
# ## How to connect to a Neo4j Database!

# %% [markdown]
# Zuerst wird ein Docker Container erstellt. Dieser enthällt einen Container, ein neo4j Image, auf welches durch die Ports 7474 und 7687 zugegriffen wird, sowie auch ein Volume und die Verbindung mit neo4j mit Username und Passwort.

# %%
# !docker-compose -p completx_sql up -d
# Out:
#  Container neo4j-container  Created
#  Container neo4j-container  Starting
#  Container neo4j-container  Started

# %% [markdown]
# Um Neo4j zu verwenden, müssen Sie es und seinen Python-Treiber installieren. Darüber hinaus erleichtert die Installation der Bibliothek py2neo die Verbindungen und Interaktionen mit der Neo4j-Datenbank.

# %%
pip install neo4j
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install py2neo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from py2neo import Graph, Node, Relationship
import csv

# %% [markdown]
# Um eine Verbindung zur Datenbank herzustellen, muss eine URL eingeben, über die die Verbindung hergestellt wird, sowie Authentifizierungsdaten, bestehend aus Benutzername und Passwort. Mit py2neo kann dann die Verbindung mithilfe von Graph hergestellt werden. Dies ist auch mit GraphDatabase von noe4j möglich.

# %%
from neo4j import GraphDatabase

uri = "neo4j://localhost:7687"
username = "neo4j"
password = "aveQho9yf6tx29vgW3kv"

graph = Graph(uri, auth=(username, password))

# %% [markdown]
# Um zu überprüfen, ob die Seite aktiv ist, kann diese Funktion verwendet werden:

# %%
import requests

url = "http://localhost:7474/browser/"
response = requests.get(url)

if response.status_code == 200:
    print("Website is accessible.")
else:
    print("Failed to access website.")
# Out:
# Website is accessible.

# %% [markdown]
# Oder mit localhost:7687 kann man neo4j im Browser starten und sich dann mit den Daten anmelden und schauen ob die Verbindung möglich ist.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Die Daten können dann mit hilfe von csv, was vorher importiert wurde, einglesen werden und nachdem die Nodes deklariert wurden, kann der Graph erstellt werden mit py2neo.

# %%
with open('Wohnregion_Patient.csv', 'r') as csvfile:
    csvreader = csv.DictReader(csvfile, delimiter=';')
    
    # Iterate over each row in the CSV file
    for row in csvreader:
        # Create a Node for each row in the CSV file
        patient_node = Node("Patient",
                            kalenderWoche=row['KW'],
                            wohnort=row['WOHNORT'],
                            Geschlecht=row['GESCHLECHT'],
                            covid=row['COVID'],
                            influenza=row['INFLUENZA'],
                            rsv=row['RSV'],
                            sonstige=row['SONSTIGE'],
                            aufnahmen=row['AUFNAHMEN'],
                            bev_zahl=row['BEV_ZAHL'])
        
        # Add the Node to the graph
        graph.create(patient_node)

# %% [markdown]
# Um abzufragen wie viele Nodes in Der Tabelle sind, kann diese Query verwendet werden:

# %%
with driver.session() as session:
    result = session.run("MATCH (n) RETURN count(n) AS node_count")
    for record in result:
        print(record["node_count"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 with driver.session() as session:
#       2     result = session.run("MATCH (n) RETURN count(n) AS node_count")
#       3     for record in result:
#
# NameError: name 'driver' is not defined

# %% [markdown]
# In Neo4j wird as Sprache "Cypher" verwendet. In dieser Sprache sind die Nodes mit () dargestellt und die Edges mit [] dargestellt. Hier werden alle Patienten die Covid gehabt haben ausgegeben:

# %%
cypher_query = """
MATCH (p:Patient) WHERE p.covid='1'
RETURN p.kalenderWoche, p.wohnort, p.Geschlecht, p.covid, p.influenza, p.rsv, p.sonstige, p.aufnahmen, p.bev_zahl

"""

result = graph.run(cypher_query)

# Print the result
for record in result:
    print(record)
# Out:
# '19. KW 2023'	'BGL'	'M'	'1'	'0'	'0'	'3'	'4'	'13780'
# '19. KW 2023'	'BGL'	'W'	'1'	'0'	'0'	'16'	'16'	'12361'
# '19. KW 2023'	'KTN'	'M'	'1'	'0'	'0'	'5'	'6'	'24639'
# '19. KW 2023'	'NÃ–'	'M'	'1'	'0'	'0'	'14'	'15'	'110830'
# '19. KW 2023'	'NÃ–'	'W'	'1'	'0'	'0'	'6'	'7'	'38530'
# '19. KW 2023'	'NÃ–'	'W'	'1'	'0'	'0'	'0'	'1'	'125900'
# '19. KW 2023'	'NÃ–'	'W'	'1'	'0'	'0'	'6'	'7'	'197835'
# '19. KW 2023'	'NÃ–'	'W'	'1'	'0'	'0'	'2'	'3'	'83246'
# '19. KW 2023'	'OÃ–'	'M'	'1'	'0'	'0'	'5'	'6'	'163750'
# '19. KW 2023'	'OÃ–'	'W'	'1'	'0'	'0'	'0'	'1'	'122614'
# '19. KW 2023'	'OÃ–'	'W'	'1'	'0'	'0'	'7'	'8'	'99157'
# '19. KW 2023'	'SBG'	'M'	'1'	'0'	'0'	'4'	'5'	'33199'
# '19. KW 2023'	'SBG'	'M'	'1'	'0'	'0'	'10'	'11'	'21501'
# '19. KW 2023'	'SBG'	'W'	'1'	'0'	'0'	'2'	'3'	'62089'
# '19. KW 2023'	'SBG'	'W'	'1'	'0'	'0'	'0'	'1'	'62089'
# '19. KW 2023'	'ST'	'M'	'1'	'0'	'0'	'3'	'4'	'107003'
# '19. KW 2023'	'ST'	'M'	'1'	'0'	'0'	'5'	'6'	'138876'
# '19. KW 2023'	'ST'	'M'	'1'	'1'	'0'	'9'	'11'	'81587'
# ...

# %% [markdown]
# Dies kann auch mit panda dargestellt werden:

# %%
import pandas as pd

# Assuming you have already executed the cypher_query and stored the result in 'result'
cypher_query = """
MATCH (p:Patient) WHERE p.covid='1'
RETURN p.kalenderWoche, p.wohnort, p.Geschlecht, p.covid, p.influenza, p.rsv, p.sonstige, p.aufnahmen, p.bev_zahl

"""

result = graph.run(cypher_query)

# Extract data from result
data = [dict(record) for record in result]

# Convert the result to a DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#      p.kalenderWoche p.wohnort p.Geschlecht p.covid p.influenza p.rsv  \
# 0        19. KW 2023       BGL            M       1           0     0
# 1        19. KW 2023       BGL            W       1           0     0
# 2        19. KW 2023       KTN            M       1           0     0
# 3        19. KW 2023       NÃ–            M       1           0     0
# 4        19. KW 2023       NÃ–            W       1           0     0
# ...              ...       ...          ...     ...         ...   ...
# 3197     12. KW 2024         V            M       1           0     0
# 3198     12. KW 2024         W            M       1           0     0
# 3199     12. KW 2024         W            M       1           1     1
# 3200     12. KW 2024         W            W       1           2     0
# 3201     12. KW 2024         W            W       1           0     0
#
#      p.sonstige p.aufnahmen p.bev_zahl
# 0             3           4      13780
# 1            16          16      12361
# ...

# %% [markdown]
# In dem Neo4j Browser kann man auch alle vorhandenen Eigenschaften einer Column sehen. Dies wird erreicht durch das Anklicken des markierten Feldes:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Danach kann der Container wieder geschlossen werden.

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND                  CREATED          STATUS         PORTS                                                      NAMES
# f2e51c0eb840   neo4j     "tini -g -- /startupâ€¦"   47 minutes ago   Up 4 minutes   0.0.0.0:7474->7474/tcp, 7473/tcp, 0.0.0.0:7687->7687/tcp   neo4j-container

# %%
# !docker-compose down

# %%
# !docker-compose -p completx_sql down
# Out:
#  Container neo4j-container  Stopping
#  Container neo4j-container  Stopped
#  Container neo4j-container  Removing
#  Container neo4j-container  Removed
#  Network completx_sql_default  Removing
#  Network completx_sql_default  Removed

# %%
# !docker volume ls
# Out:
# DRIVER    VOLUME NAME
# local     6c8f923dc4b9933a5fe58ba5d2c0462b45e96de10d4c6a93a61a7a5b87228a23
# local     21f5b0f7dcf9818a2d11c859bc4f4d4fc7f2d2ade822d5fe06226c9aa7cafa01
# local     65bc1da2405287e11bba0a703f40fb06695c2dcd2102377e106460128cf7a481
# local     46001daa712175893639701d4b2291e7c7eebb28e3aed848ec55a05769c73f19
# local     5034774e45697881cd48942d467823125e19878a6dd7edbb7e643e4da7071a2e
# local     10226980916ec84de7dbfc7871fbe4a1230953f2491dd6a074174212adbbf79a
# local     af3f168faee552ab5d504b8a7024396978c7cdcf6c13fc8b19251c1b851fa180
# local     completx_sql_neo4j-data
# local     d4d8a5b9c55c77a6c84eb67f4caa075bb53e3211dbe220424a8252868a22d9bb
# local     docker_compose_my-db
# local     e0d2727d300310e222cd57053e24ddc94ee5af66fbe12421ef9222e9040f89ea
# local     e55177a2d26139056130e30128382f79d5319e05b141e3941a5ffa4c5fd9b602
# local     myvolume
# local     projektname_my-db

# %% [markdown]
# Um ein Volume zu löschen, kann man wieder folgenden Befehl verwenden:

# %%
# !docker volume rm completx_sql_neo4j-data
# Out:
# completx_sql_neo4j-data

# %% [markdown]
# Anbei ist ein GitHub-Repository zu finden, in dem einige Queries sowie Videos verlinkt sind, die Ihnen helfen können, Cypher und Neo4j besser zu verstehen:
# https://github.com/cj2001/bite_sized_data_science/tree/main
#
# Ebenfalls sind in der Dokumentation von Neo4j viele hilfreiche Hinweise zu finden, zum Beispiel zum Import von CSV-Dateien über Python:
# https://neo4j.com/docs/getting-started/data-import/csv-import/
#
# Zuletzt noch ein Cheatsheet für Cypher: https://neo4j.com/docs/cypher-cheat-sheet/5/auradb-enterprise/
